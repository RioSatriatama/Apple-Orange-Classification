# %% [markdown]
# <a href="https://colab.research.google.com/github/RioSatriatama/Apple-Orange-Classification/blob/main/Apple_%26_Orange_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Library**

# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd

# %% [markdown]
# # **Read Dataset & Print the contents of the DataFrame**

# %%
df = pd.read_csv('/content/apples_and_oranges.csv')
print(df.to_string())
# Out:
#     Weight  Size   Class
# 0       69  4.39  orange
# 1       69  4.21  orange
# 2       65  4.09  orange
# 3       72  5.85   apple
# 4       67  4.70  orange
# 5       73  5.68   apple
# 6       70  5.56   apple
# 7       75  5.11   apple
# 8       74  5.36   apple
# 9       65  4.27  orange
# 10      73  5.79   apple
# 11      70  5.47   apple
# 12      74  5.53   apple
# 13      68  4.47  orange
# 14      74  5.22   apple
# 15      65  4.48  orange
# 16      69  4.66  orange
# 17      75  5.25   apple
# 18      67  4.18  orange
# 19      74  5.50   apple
# 20      66  4.13  orange
# 21      70  4.83  orange
# 22      69  4.61  orange
# 23      68  4.08  orange
# 24      67  4.25  orange
# 25      71  5.35   apple
# 26      67  4.01  orange
# 27      70  4.22  orange
# 28      74  5.25   apple
# 29      71  5.26   apple
# 30      73  5.78   apple
# 31      66  4.68  orange
# 32      72  5.72   apple
# 33      73  5.17   apple
# 34      68  4.83  orange
# 35      69  4.11  orange
# ...

# %%
weight_Series=df['Weight']
a=weight_Series+1
a
# Out:
# 0     70
# 1     70
# 2     66
# 3     73
# 4     68
# 5     74
# 6     71
# 7     76
# 8     75
# 9     66
# 10    74
# 11    71
# 12    75
# 13    69
# 14    75
# 15    66
# 16    70
# 17    76
# 18    68
# 19    75
# 20    67
# 21    71
# 22    70
# 23    69
# 24    68
# 25    72
# 26    68
# 27    71
# 28    75
# 29    72
# 30    74
# 31    67
# 32    73
# 33    74
# 34    69
# 35    70
# 36    70
# 37    75
# 38    71
# 39    74
# Name: Weight, dtype: int64

# %%
weight_Series> 70
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4     False
# 5      True
# 6     False
# 7      True
# 8      True
# 9     False
# 10     True
# 11    False
# 12     True
# 13    False
# 14     True
# 15    False
# 16    False
# 17     True
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25     True
# 26    False
# 27    False
# 28     True
# 29     True
# 30     True
# 31    False
# 32     True
# 33     True
# 34    False
# 35    False
# 36    False
# 37     True
# 38    False
# 39     True
# Name: Weight, dtype: bool

# %%
df.head(5)
# Out:
#    Weight  Size   Class
# 0      69  4.39  orange
# 1      69  4.21  orange
# 2      65  4.09  orange
# 3      72  5.85   apple
# 4      67  4.70  orange

# %%
def add(x):
   return x+1

weight_Series.apply(add)
# Out:
# 0     70
# 1     70
# 2     66
# 3     73
# 4     68
# 5     74
# 6     71
# 7     76
# 8     75
# 9     66
# 10    74
# 11    71
# 12    75
# 13    69
# 14    75
# 15    66
# 16    70
# 17    76
# 18    68
# 19    75
# 20    67
# 21    71
# 22    70
# 23    69
# 24    68
# 25    72
# 26    68
# 27    71
# 28    75
# 29    72
# 30    74
# 31    67
# 32    73
# 33    74
# 34    69
# 35    70
# 36    70
# 37    75
# 38    71
# 39    74
# Name: Weight, dtype: int64

# %%
weight_Series
# Out:
# 0     69
# 1     69
# 2     65
# 3     72
# 4     67
# 5     73
# 6     70
# 7     75
# 8     74
# 9     65
# 10    73
# 11    70
# 12    74
# 13    68
# 14    74
# 15    65
# 16    69
# 17    75
# 18    67
# 19    74
# 20    66
# 21    70
# 22    69
# 23    68
# 24    67
# 25    71
# 26    67
# 27    70
# 28    74
# 29    71
# 30    73
# 31    66
# 32    72
# 33    73
# 34    68
# 35    69
# 36    69
# 37    74
# 38    70
# 39    73
# Name: Weight, dtype: int64

# %%
data={'apples':[3,2,0,3],'oranges':[0,3,7,2]}

df1 = pd.DataFrame(data)
print(df1.to_string())
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       3        2

# %%
print("Count",df1.count())
# Out:
# Count apples     4
# oranges    4
# dtype: int64

# %% [markdown]
# How to access a column in the dataframe?

# %%
df1['apples']
# Out:
# 0    3
# 1    2
# 2    0
# 3    3
# Name: apples, dtype: int64

# %% [markdown]
# decribe() function provides statistical summaries of the data in the DataFrame, including measures like count, mean, standard deviation, minimum, maximum, and quartiles for numeric columns. This information helps you quickly understand the distribution and central tendencies of the data within the DataFrame.

# %%
df1.describe()
# Out:
#          apples  oranges
# count  4.000000  4.00000
# mean   2.000000  3.00000
# std    1.414214  2.94392
# min    0.000000  0.00000
# 25%    1.500000  1.50000
# 50%    2.500000  2.50000
# 75%    3.000000  4.00000
# max    3.000000  7.00000

# %% [markdown]
# In Pandas, when we use the .head() method without specifying a number, it will, by default, display the first 5 rows of the DataFrame. This is the default behavior, but you can specify a different number as an argument to display a different number of rows.

# %%
df1.head(2)
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3

# %%
df1.head(10)
# Out:
#    apples  oranges
# 0       3        0
# 1       2        3
# 2       0        7
# 3       3        2

# %% [markdown]
# In Pandas, the .unique() method is used to obtain the unique (distinct) values from a Pandas Series or a DataFrame column.

# %%
df1['apples'].unique()
# Out:
# array([3, 2, 0])

# %% [markdown]
# hist() function will display a histogram chart that shows the frequency or count of different values in the "apples" column, helping us visualize the distribution of data within that column.

# %%
df1['apples'].hist()
# Out:
# <Axes: >
